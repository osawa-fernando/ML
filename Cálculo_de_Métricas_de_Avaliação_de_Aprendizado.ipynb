# %% [markdown]
# <a href="https://colab.research.google.com/github/osawa-fernando/ML/blob/main/C%C3%A1lculo_de_M%C3%A9tricas_de_Avalia%C3%A7%C3%A3o_de_Aprendizado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Simulando dados de classificação binária
y_true = [0, 1, 0, 0, 0, 1, 1, 1]
y_pred = [0, 1, 1, 1, 0, 0, 1, 1]

# Gerar matriz de confusão
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
print("Matriz de Confusão:\n", cm)

# Extrair VP, VN, FP, FN
vn, fp, fn, vp = cm.ravel()
print(f"Verdadeiro Negativo (VN): {vn}")
print(f"Falso Positivo (FP): {fp}")
print(f"Falso Negativo (FN): {fn}")
print(f"Verdadeiro Positivo (VP): {vp}")

# Plotar matriz de confusão
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Classe 0", "Classe 1"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusão Binária")
plt.grid(False)
plt.show()
# Out:
# Matriz de Confusão:
#  [[2 2]
#  [1 3]]
# Verdadeiro Negativo (VN): 2
# Falso Positivo (FP): 2
# Falso Negativo (FN): 1
# Verdadeiro Positivo (VP): 3

# %%
# Cálculo das métricas
sensibilidade = vp / (vp + fn) if (vp + fn) != 0 else 0  # Recall
especificidade = vn / (vn + fp) if (vn + fp) != 0 else 0
acuracia = (vp + vn) / (vp + vn + fp + fn)
precisao = vp / (vp + fp) if (vp + fp) != 0 else 0
f_score = 2 * (precisao * sensibilidade) / (precisao + sensibilidade) if (precisao + sensibilidade) != 0 else 0

# Exibir os resultados
print("\n📈 Métricas de Avaliação:")
print(f"Sensibilidade (Recall): {sensibilidade:.2f}")
print(f"Especificidade: {especificidade:.2f}")
print(f"Acurácia: {acuracia:.2f}")
print(f"Precisão (Precision): {precisao:.2f}")
print(f"F-Score: {f_score:.2f}")
# Out:
# 📈 Métricas de Avaliação:
# Sensibilidade (Recall): 0.75
# Especificidade: 0.50
# Acurácia: 0.62
# Precisão (Precision): 0.60
# F-Score: 0.67
